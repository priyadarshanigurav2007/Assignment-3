# %% [markdown]
# <a href="https://colab.research.google.com/github/priyadarshanigurav2007/Assignment-3/blob/main/Collab_Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. WAP to find out greatest of 3 numbers

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a >= b and a >= c:
    print("Greatest number =", a)
elif b >= a and b >= c:
    print("Greatest number =", b)
else:


    print("Greatest number =", c)
# 2. WAP to find whether given number is odd or even

num = int(input("Enter a number: "))

if num % 2 == 0:
    print("Even number")
else:
    print("Odd number")
# 3. WAP to check whether a character is uppercase or lowercase alphabet

ch = input("Enter a character: ")

if ch.isalpha():
    if ch.isupper():
        print("Uppercase letter")
    else:
        print("Lowercase letter")
else:
    print("Not an alphabet")

    # 4. WAP to find whether given input is number or character

ch = input("Enter any input: ")

if ch.isdigit():
    print("It is a number")
else:
    print("It is character")
# Out:
# Enter first number: 10
# Enter second number: 20
# Enter third number: 50
# Greatest number = 50
# Enter a number: 90
# Even number
# Enter a character: Priyadarshani
# Not an alphabet
# Enter any input: Z
# It is character
